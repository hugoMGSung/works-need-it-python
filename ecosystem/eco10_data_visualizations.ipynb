# %% [markdown]
# ## 데이터 시각화 1
#
# ### Apache Superset: 데이터 탐색과 시각화를 위한 오픈 소스 BI 툴
#
# - https://superset.apache.org/
# - 데이터 탐색과 시각화를 위한 대규모, 최신, 오픈 소스의 BI 툴
# - Flask, Pandas, SQLAlchemy 등과 같은 다양한 Python 라이브러리를 사용

# %%
# 설치
# !pip install apache-superset
# Out:
# ...
#      ---------------------------------------- 0.0/55.5 MB ? eta -:--:--
#      - -------------------------------------- 1.8/55.5 MB 14.3 MB/s eta 0:00:04
#      -- ------------------------------------- 3.9/55.5 MB 11.2 MB/s eta 0:00:05
#      ---- ----------------------------------- 6.8/55.5 MB 12.3 MB/s eta 0:00:04
#      ------------- ------------------------- 19.7/55.5 MB 25.9 MB/s eta 0:00:02
#      ------------------- ------------------- 28.3/55.5 MB 31.5 MB/s eta 0:00:01
#      --------------------- ----------------- 30.4/55.5 MB 29.2 MB/s eta 0:00:01
#      ----------------------- --------------- 33.6/55.5 MB 24.5 MB/s eta 0:00:01
#      ------------------------ -------------- 34.6/55.5 MB 21.7 MB/s eta 0:00:01
#      -------------------------- ------------ 37.7/55.5 MB 20.9 MB/s eta 0:00:01
#      ----------------------------- --------- 41.4/55.5 MB 20.6 MB/s eta 0:00:01
#      ----------------------------- --------- 41.9/55.5 MB 20.2 MB/s eta 0:00:01
# ...
