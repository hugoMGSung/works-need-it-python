# %% [markdown]
# ## 데이터 시각화 2
#
# ### Jupyter 기반 데이터 시각화
#
# 데이터 시각화는 정보를 효과적으로 전달하고 이해하는 데 필수적인 요소. 복잡한 데이터 세트를 시각적으로 표현함으로써, 데이터에서 숨겨진 패턴, 추세, 그리고 관계를 더 쉽게 발견하고 해석할 수 있습니다. 이러한 맥락에서 Jupyter 기반의 시각화 라이브러리들은 특히 중요한 역할을 합니다.

# %% [markdown]
# #### HoloViews: 복잡한 시각화를 빠르고 유연하게
#
# [링크](https://github.com/holoviz/holoviews)
#
# 복잡한 데이터 시각화를 간단하고 선언적인 방식으로 구현할 수 있도록 하는 파이썬 라이브러리

# %%
# 설치
# !pip install holoviews
# Out:
# Collecting holoviews
#   Downloading holoviews-1.20.0-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: bokeh>=3.1 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from holoviews) (3.6.2)
# Collecting colorcet (from holoviews)
#   Downloading colorcet-3.1.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.21 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from holoviews) (1.23.5)
# Requirement already satisfied: packaging in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from holoviews) (24.2)
# Requirement already satisfied: pandas>=1.3 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from holoviews) (2.0.3)
# Collecting panel>=1.0 (from holoviews)
#   Downloading panel-1.5.5-py3-none-any.whl.metadata (15 kB)
# Collecting param<3.0,>=2.0 (from holoviews)
#   Downloading param-2.2.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting pyviz-comms>=2.1 (from holoviews)
#   Downloading pyviz_comms-3.0.3-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: Jinja2>=2.9 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from bokeh>=3.1->holoviews) (3.1.5)
# Requirement already satisfied: contourpy>=1.2 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from bokeh>=3.1->holoviews) (1.3.1)
# Requirement already satisfied: pillow>=7.1.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from bokeh>=3.1->holoviews) (11.0.0)
# Requirement already satisfied: PyYAML>=3.10 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from bokeh>=3.1->holoviews) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from bokeh>=3.1->holoviews) (6.4.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from bokeh>=3.1->holoviews) (2024.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from pandas>=1.3->holoviews) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from pandas>=1.3->holoviews) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from pandas>=1.3->holoviews) (2024.2)
# Collecting bleach (from panel>=1.0->holoviews)
#   Downloading bleach-6.2.0-py3-none-any.whl.metadata (30 kB)
# Collecting linkify-it-py (from panel>=1.0->holoviews)
#   Downloading linkify_it_py-2.0.3-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: markdown in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from panel>=1.0->holoviews) (3.7)
# Requirement already satisfied: markdown-it-py in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from panel>=1.0->holoviews) (3.0.0)
# Collecting mdit-py-plugins (from panel>=1.0->holoviews)
#   Downloading mdit_py_plugins-0.4.2-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from panel>=1.0->holoviews) (2.32.3)
# Requirement already satisfied: tqdm in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from panel>=1.0->holoviews) (4.67.1)
# Requirement already satisfied: typing-extensions in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from panel>=1.0->holoviews) (4.12.2)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from Jinja2>=2.9->bokeh>=3.1->holoviews) (3.0.2)
# Requirement already satisfied: six>=1.5 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3->holoviews) (1.17.0)
# Collecting webencodings (from bleach->panel>=1.0->holoviews)
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting uc-micro-py (from linkify-it-py->panel>=1.0->holoviews)
#   Downloading uc_micro_py-1.0.3-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: mdurl~=0.1 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from markdown-it-py->panel>=1.0->holoviews) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from requests->panel>=1.0->holoviews) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from requests->panel>=1.0->holoviews) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from requests->panel>=1.0->holoviews) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from requests->panel>=1.0->holoviews) (2024.12.14)
# Requirement already satisfied: colorama in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from tqdm->panel>=1.0->holoviews) (0.4.6)
# Downloading holoviews-1.20.0-py3-none-any.whl (5.0 MB)
#    ---------------------------------------- 0.0/5.0 MB ? eta -:--:--
#    ---------------------------------------- 5.0/5.0 MB 43.2 MB/s eta 0:00:00
# Downloading panel-1.5.5-py3-none-any.whl (27.4 MB)
#    ---------------------------------------- 0.0/27.4 MB ? eta -:--:--
#    -- ------------------------------------- 1.8/27.4 MB 7.2 MB/s eta 0:00:04
#    ---------------- ----------------------- 11.5/27.4 MB 25.7 MB/s eta 0:00:01
#    --------------------- ------------------ 14.7/27.4 MB 25.6 MB/s eta 0:00:01
#    -------------------------- ------------- 18.1/27.4 MB 20.7 MB/s eta 0:00:01
#    ---------------------------------------  27.3/27.4 MB 25.4 MB/s eta 0:00:01
#    ---------------------------------------- 27.4/27.4 MB 24.4 MB/s eta 0:00:00
# Downloading param-2.2.0-py3-none-any.whl (119 kB)
# Downloading pyviz_comms-3.0.3-py3-none-any.whl (83 kB)
# Downloading colorcet-3.1.0-py3-none-any.whl (260 kB)
# Downloading bleach-6.2.0-py3-none-any.whl (163 kB)
# Downloading linkify_it_py-2.0.3-py3-none-any.whl (19 kB)
# Downloading mdit_py_plugins-0.4.2-py3-none-any.whl (55 kB)
# Downloading uc_micro_py-1.0.3-py3-none-any.whl (6.2 kB)
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Installing collected packages: webencodings, uc-micro-py, param, colorcet, bleach, pyviz-comms, mdit-py-plugins, linkify-it-py, panel, holoviews
# Successfully installed bleach-6.2.0 colorcet-3.1.0 holoviews-1.20.0 linkify-it-py-2.0.3 mdit-py-plugins-0.4.2 panel-1.5.5 param-2.2.0 pyviz-comms-3.0.3 uc-micro-py-1.0.3 webencodings-0.5.1

# %%
import numpy as np
import holoviews as hv
hv.extension('bokeh')

# 샘플 데이터 생성
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)

# 커브 그래프 생성
curve = hv.Curve((x, y))

# 시각화 보여주기
curve
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='8f6ff2ad-7fa2-4463-a1d9-b432dcf32a84'>
#   <div id="ead1500f-509f-43c7-993c-48f56d1e70ba" data-root-id="8f6ff2ad-7fa2-4463-a1d9-b432dcf32a84" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"b49fd0ce-2aa2-41d1-91e4-5669a245f7e9":{"version":"3.6.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"8f6ff2ad-7fa2-4463-a1d9-b432dcf32a84"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"c13b7836-c63a-42c1-87a1-37908e1fb071","attributes":{"plot_id":"8f6ff2ad-7fa2-4463-a1d9-b432dcf32a84","comm_id":"acf2b977907c45a981158d20bf1b0316","client_comm_id":"2c57463b1d944ca49cbdf6d08e313bcc"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"b49fd0ce-2aa2-41d1-91e4-5669a245f7e9","roots":{"8f6ff2ad-7fa2-4463-a1d9-b432dcf32a84":"ead1500f-509f-43c7-993c-48f56d1e70ba"},"root_ids":["8f6ff2ad-7fa2-4463-a1d9-b432dcf32a84"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :Curve   [x]   (y)

# %% [markdown]
# #### IPyWidgets: Jupyter 환경에서의 인터랙티브 위젯 모음
#
# ipywidgets는 Jupyter Notebook과 JupyterLab에서 인터랙티브 위젯을 생성할 수 있게 해주는 파이썬 라이브러리

# %%
# 설치
# !pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (8.1.5)
# Requirement already satisfied: comm>=0.1.3 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipywidgets) (8.31.0)
# Requirement already satisfied: traitlets>=4.3.1 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: colorama in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: exceptiongroup in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack_data in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)

# %% [markdown]
# 설치 후, Jupyter Notebook에서 사용하기 위해 아래 명령어를 실행

# %%
# !jupyter nbextension enable --py widgetsnbextension --sys-prefix
# Out:
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: kernel kernelspec migrate run troubleshoot
#
# Jupyter command `jupyter-nbextension` not found.

# %%
import ipywidgets as widgets
from IPython.display import display

# 슬라이더 위젯 생성
slider = widgets.IntSlider(value=5, min=0, max=10, step=1, description='Number:')

# 슬라이더 값이 변경될 때마다 호출되는 함수
def on_value_change(change):
    print(f"Slider value changed to {change['new']}")

# 슬라이더와 함수 연결
slider.observe(on_value_change, names='value')

# 슬라이더 위젯 표시
display(slider)
# Out:
# IntSlider(value=5, description='Number:', max=10)
# Slider value changed to 6
# Slider value changed to 7
# Slider value changed to 8
# Slider value changed to 9
# Slider value changed to 10

# %% [markdown]
# #### pythreejs: Jupyter 환경에서의 3D 그래픽 렌더링 도구
#
# Jupyter Notebook과 JupyterLab에서 3D 그래픽을 렌더링할 수 있게 해주는 파이썬 라이브러리

# %%
# 설치
# !pip install pythreejs
# Out:
# Collecting pythreejs
#   Using cached pythreejs-2.4.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: ipywidgets>=7.2.1 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from pythreejs) (8.1.5)
# Collecting ipydatawidgets>=1.1.1 (from pythreejs)
#   Using cached ipydatawidgets-4.3.5-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: numpy in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from pythreejs) (1.23.5)
# Requirement already satisfied: traitlets in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from pythreejs) (5.14.3)
# Collecting traittypes>=0.2.0 (from ipydatawidgets>=1.1.1->pythreejs)
#   Using cached traittypes-0.2.1-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: comm>=0.1.3 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipywidgets>=7.2.1->pythreejs) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipywidgets>=7.2.1->pythreejs) (8.31.0)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipywidgets>=7.2.1->pythreejs) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipywidgets>=7.2.1->pythreejs) (3.0.13)
# Requirement already satisfied: colorama in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.2.1->pythreejs) (0.4.6)
# Requirement already satisfied: decorator in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.2.1->pythreejs) (5.1.1)
# Requirement already satisfied: exceptiongroup in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.2.1->pythreejs) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.2.1->pythreejs) (0.19.2)
# Requirement already satisfied: matplotlib-inline in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.2.1->pythreejs) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.2.1->pythreejs) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.2.1->pythreejs) (2.18.0)
# Requirement already satisfied: stack_data in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.2.1->pythreejs) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.2.1->pythreejs) (4.12.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.2.1->pythreejs) (0.8.4)
# Requirement already satisfied: wcwidth in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.2.1->pythreejs) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.2.1->pythreejs) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.2.1->pythreejs) (3.0.0)
# Requirement already satisfied: pure-eval in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.2.1->pythreejs) (0.2.3)
# Using cached pythreejs-2.4.2-py3-none-any.whl (3.4 MB)
# Using cached ipydatawidgets-4.3.5-py2.py3-none-any.whl (271 kB)
# Using cached traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Installing collected packages: traittypes, ipydatawidgets, pythreejs
# Successfully installed ipydatawidgets-4.3.5 pythreejs-2.4.2 traittypes-0.2.1

# %% [markdown]
# 간단한 3D 큐브를 생성하고, 마우스로 회전할 수 있는 인터랙티브한 3D 그래픽을 출력

# %%
import pythreejs as p3
from IPython.display import display

# 큐브 메쉬 생성
cube = p3.Mesh(
    geometry=p3.BoxGeometry(1, 1, 1),
    material=p3.MeshBasicMaterial(color='green', wireframe=True)
)

# 씬에 큐브 추가
scene = p3.Scene(children=[cube, p3.AmbientLight(color='#dddddd')])

# 카메라 및 렌더러 설정
camera = p3.PerspectiveCamera(position=[2, 2, 2], up=[0, 0, 1], children=[p3.DirectionalLight(color='white', position=[3, 5, 1], intensity=0.5)])
renderer = p3.Renderer(camera=camera, scene=scene, controls=[p3.OrbitControls(controlling=camera)])

# 렌더러 출력
display(renderer)
# Out:
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.5, position=(3.0, 5.0,…

# %% [markdown]
# #### LUX: EDA 자동화 데이터 분석 라이브러리
#
# 탐색적 데이터 분석(Exploratory Data Analysis, EDA)을 자동화하는 데 중점을 둔 데이터 시각화 라이브러리

# %%
# 설치
# !pip install lux-api
# Out:
# Collecting lux-api
#   Downloading lux-api-0.5.1.tar.gz (127 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: scipy>=1.3.3 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from lux-api) (1.14.1)
# Collecting altair>=4.0.0 (from lux-api)
#   Using cached altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.16.5 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from lux-api) (1.23.5)
# Requirement already satisfied: pandas in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from lux-api) (2.0.3)
# Requirement already satisfied: scikit-learn>=0.22 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from lux-api) (1.5.2)
# Requirement already satisfied: matplotlib>=3.0.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from lux-api) (3.10.0)
# Collecting lux-widget>=0.1.4 (from lux-api)
#   Downloading lux-widget-0.1.11.tar.gz (2.5 MB)
#      ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#      ---------------------------------------- 2.5/2.5 MB 28.9 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting autopep8>=1.5 (from lux-api)
#   Downloading autopep8-2.3.1-py2.py3-none-any.whl.metadata (16 kB)
# Collecting iso3166 (from lux-api)
#   Downloading iso3166-2.1.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: psutil>=5.9.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from lux-api) (6.1.1)
# Collecting sh (from lux-api)
#   Downloading sh-2.1.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: jinja2 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from altair>=4.0.0->lux-api) (3.1.5)
# Requirement already satisfied: jsonschema>=3.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from altair>=4.0.0->lux-api) (4.23.0)
# Collecting narwhals>=1.14.2 (from altair>=4.0.0->lux-api)
#   Downloading narwhals-1.21.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from altair>=4.0.0->lux-api) (24.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from altair>=4.0.0->lux-api) (4.12.2)
# Collecting pycodestyle>=2.12.0 (from autopep8>=1.5->lux-api)
#   Downloading pycodestyle-2.12.1-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting tomli (from autopep8>=1.5->lux-api)
#   Using cached tomli-2.2.1-py3-none-any.whl.metadata (10 kB)
# Collecting notebook>=4.0.0 (from lux-widget>=0.1.4->lux-api)
#   Downloading notebook-7.3.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: ipywidgets>=7.5.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from lux-widget>=0.1.4->lux-api) (8.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from matplotlib>=3.0.0->lux-api) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from matplotlib>=3.0.0->lux-api) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from matplotlib>=3.0.0->lux-api) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from matplotlib>=3.0.0->lux-api) (1.4.8)
# Requirement already satisfied: pillow>=8 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from matplotlib>=3.0.0->lux-api) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from matplotlib>=3.0.0->lux-api) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from matplotlib>=3.0.0->lux-api) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.2.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from scikit-learn>=0.22->lux-api) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from scikit-learn>=0.22->lux-api) (3.5.0)
# Requirement already satisfied: pytz>=2020.1 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from pandas->lux-api) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from pandas->lux-api) (2024.2)
# Requirement already satisfied: comm>=0.1.3 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (8.31.0)
# Requirement already satisfied: traitlets>=4.3.1 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (3.0.13)
# Requirement already satisfied: attrs>=22.2.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (0.22.3)
# Collecting jupyter-server<3,>=2.4.0 (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Downloading jupyter_server-2.15.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyterlab<4.4,>=4.3.4 (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Downloading jupyterlab-4.3.4-py3-none-any.whl.metadata (16 kB)
# Collecting notebook-shim<0.3,>=0.2 (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: tornado>=6.2.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (6.4.2)
# Requirement already satisfied: six>=1.5 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->lux-api) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from jinja2->altair>=4.0.0->lux-api) (3.0.2)
# Requirement already satisfied: colorama in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.4.6)
# Requirement already satisfied: decorator in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (5.1.1)
# Requirement already satisfied: exceptiongroup in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.19.2)
# Requirement already satisfied: matplotlib-inline in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (2.18.0)
# Requirement already satisfied: stack_data in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.6.3)
# Collecting anyio>=3.1.0 (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Downloading anyio-4.8.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: jupyter-client>=7.4.4 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (5.7.2)
# Collecting jupyter-events>=0.11.0 (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Downloading jupyter_events-0.11.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting nbconvert>=6.4.4 (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Downloading nbconvert-7.16.5-py3-none-any.whl.metadata (8.5 kB)
# Collecting nbformat>=5.3.0 (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting prometheus-client>=0.9 (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Downloading prometheus_client-0.21.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pywinpty>=2.0.1 (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Downloading pywinpty-2.0.14-cp310-none-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: pyzmq>=24 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (26.2.0)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting websocket-client>=1.7 (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting async-lru>=1.0.0 (from jupyterlab<4.4,>=4.3.4->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting httpx>=0.25.0 (from jupyterlab<4.4,>=4.3.4->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: ipykernel>=6.5.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (6.29.5)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab<4.4,>=4.3.4->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: setuptools>=40.8.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (65.5.0)
# Requirement already satisfied: babel>=2.10 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.16.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Downloading json5-0.10.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: requests>=2.31 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.32.3)
# Requirement already satisfied: idna>=2.8 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (3.10)
# Requirement already satisfied: sniffio>=1.1 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.3.1)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: certifi in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2024.12.14)
# Collecting httpcore==1.* (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.14.0)
# Requirement already satisfied: debugpy>=1.6.5 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.8.11)
# Requirement already satisfied: nest-asyncio in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (4.3.6)
# Requirement already satisfied: pywin32>=300 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (308)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Downloading python_json_logger-3.2.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: pyyaml>=5.3 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (6.0.2)
# Collecting rfc3339-validator (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: beautifulsoup4 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (6.2.0)
# Collecting defusedxml (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Downloading mistune-3.1.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting nbclient>=0.5.0 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Downloading nbclient-0.10.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting fastjsonschema>=2.15 (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Downloading fastjsonschema-2.21.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: wcwidth in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.3.0)
# Requirement already satisfied: executing>=1.2.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (3.0.0)
# Requirement already satisfied: pure-eval in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.2.3)
# Requirement already satisfied: webencodings in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.5.1)
# Collecting tinycss2<1.5,>=1.1.0 (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Downloading tinycss2-1.4.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: cffi>=1.0.1 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.6)
# Requirement already satisfied: pycparser in d:\01_programming\100_hugobank\mine\works-need-it-python\venv_thrd\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.22)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api)
#   Using cached types_python_dateutil-2.9.0.20241206-py3-none-any.whl.metadata (2.1 kB)
# Using cached altair-5.5.0-py3-none-any.whl (731 kB)
# Downloading autopep8-2.3.1-py2.py3-none-any.whl (45 kB)
# Downloading iso3166-2.1.1-py3-none-any.whl (9.8 kB)
# Downloading sh-2.1.0-py3-none-any.whl (38 kB)
# Downloading narwhals-1.21.0-py3-none-any.whl (281 kB)
# Downloading notebook-7.3.2-py3-none-any.whl (13.2 MB)
#    ---------------------------------------- 0.0/13.2 MB ? eta -:--:--
#    ----------------------- ---------------- 7.6/13.2 MB 36.0 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.2 MB 32.9 MB/s eta 0:00:01
#    ---------------------------------------- 13.2/13.2 MB 30.6 MB/s eta 0:00:00
# Downloading pycodestyle-2.12.1-py2.py3-none-any.whl (31 kB)
# Using cached tomli-2.2.1-py3-none-any.whl (14 kB)
# Downloading jupyter_server-2.15.0-py3-none-any.whl (385 kB)
# Downloading jupyterlab-4.3.4-py3-none-any.whl (11.7 MB)
#    ---------------------------------------- 0.0/11.7 MB ? eta -:--:--
#    --------------------------------- ------ 9.7/11.7 MB 46.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.7/11.7 MB 45.6 MB/s eta 0:00:00
# Using cached jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Using cached notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Downloading anyio-4.8.0-py3-none-any.whl (96 kB)
# Using cached argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Using cached async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.7-py3-none-any.whl (78 kB)
# Downloading json5-0.10.0-py3-none-any.whl (34 kB)
# Downloading jupyter_events-0.11.0-py3-none-any.whl (19 kB)
# Using cached jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
# Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading nbconvert-7.16.5-py3-none-any.whl (258 kB)
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading prometheus_client-0.21.1-py3-none-any.whl (54 kB)
# Downloading pywinpty-2.0.14-cp310-none-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 36.6 MB/s eta 0:00:00
# Using cached Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Using cached terminado-0.18.1-py3-none-any.whl (14 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Downloading fastjsonschema-2.21.1-py3-none-any.whl (23 kB)
# Downloading mistune-3.1.0-py3-none-any.whl (53 kB)
# Downloading nbclient-0.10.2-py3-none-any.whl (25 kB)
# Using cached pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading python_json_logger-3.2.1-py3-none-any.whl (14 kB)
# Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Using cached arrow-1.3.0-py3-none-any.whl (66 kB)
# Using cached types_python_dateutil-2.9.0.20241206-py3-none-any.whl (14 kB)
# Building wheels for collected packages: lux-api, lux-widget
#   Building wheel for lux-api (pyproject.toml): started
#   Building wheel for lux-api (pyproject.toml): finished with status 'done'
#   Created wheel for lux-api: filename=lux_api-0.5.1-py3-none-any.whl size=185636 sha256=327004235ec06ef96c9f75a959ba62fe1533e3e37dccf616439769adca295ecd
#   Stored in directory: c:\users\perso\appdata\local\pip\cache\wheels\29\2f\f5\d5fcd3111309d380314ce9ad7ed6eb2fe03b3315123bd0c2e9
#   Building wheel for lux-widget (pyproject.toml): started
#   Building wheel for lux-widget (pyproject.toml): finished with status 'done'
#   Created wheel for lux-widget: filename=lux_widget-0.1.11-py3-none-any.whl size=2540477 sha256=b62936c52608d6facf5ba4c874587cad4c2d0af03a8284b54fadf7f05c85981b
#   Stored in directory: c:\users\perso\appdata\local\pip\cache\wheels\4d\f6\ce\bbd6194f5f69bc0b86bc7b278c766caf129cce86c016191905
# Successfully built lux-api lux-widget
# Installing collected packages: fastjsonschema, websocket-client, webcolors, uri-template, types-python-dateutil, tomli, tinycss2, sh, send2trash, rfc3986-validator, rfc3339-validator, pywinpty, python-json-logger, pycodestyle, prometheus-client, pandocfilters, overrides, narwhals, mistune, jupyterlab-pygments, jsonpointer, json5, iso3166, httpcore, fqdn, defusedxml, async-lru, anyio, terminado, httpx, autopep8, arrow, argon2-cffi-bindings, jupyter-server-terminals, isoduration, argon2-cffi, nbformat, altair, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, lux-widget, lux-api
# Successfully installed altair-5.5.0 anyio-4.8.0 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.4 autopep8-2.3.1 defusedxml-0.7.1 fastjsonschema-2.21.1 fqdn-1.5.1 httpcore-1.0.7 httpx-0.28.1 iso3166-2.1.1 isoduration-20.11.0 json5-0.10.0 jsonpointer-3.0.0 jupyter-events-0.11.0 jupyter-lsp-2.2.5 jupyter-server-2.15.0 jupyter-server-terminals-0.5.3 jupyterlab-4.3.4 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 lux-api-0.5.1 lux-widget-0.1.11 mistune-3.1.0 narwhals-1.21.0 nbclient-0.10.2 nbconvert-7.16.5 nbformat-5.10.4 notebook-7.3.2 notebook-shim-0.2.4 overrides-7.7.0 pandocfilters-1.5.1 prometheus-client-0.21.1 pycodestyle-2.12.1 python-json-logger-3.2.1 pywinpty-2.0.14 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 send2trash-1.8.3 sh-2.1.0 terminado-0.18.1 tinycss2-1.4.0 tomli-2.2.1 types-python-dateutil-2.9.0.20241206 uri-template-1.3.0 webcolors-24.11.1 websocket-client-1.8.0

# %% [markdown]
# <img src="https://wikidocs.net/images/page/226692/lux_ex.png" width="700">
