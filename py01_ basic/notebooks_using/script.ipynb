-- %% [markdown]
-- # [BookRentalShop]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [BookRentalShop]    Script Date: 2024-04-02 오후 12:59:29 ******/
CREATE DATABASE [BookRentalShop]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'BookRentalShop', FILENAME = N'D:\05_DB_Data\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\BookRentalShop.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'BookRentalShop_log', FILENAME = N'D:\05_DB_Data\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\BookRentalShop_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [BookRentalShop] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [BookRentalShop].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [BookRentalShop] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [BookRentalShop] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [BookRentalShop] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [BookRentalShop] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [BookRentalShop] SET ARITHABORT OFF 
GO
ALTER DATABASE [BookRentalShop] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [BookRentalShop] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [BookRentalShop] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [BookRentalShop] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [BookRentalShop] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [BookRentalShop] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [BookRentalShop] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [BookRentalShop] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [BookRentalShop] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [BookRentalShop] SET  ENABLE_BROKER 
GO
ALTER DATABASE [BookRentalShop] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [BookRentalShop] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [BookRentalShop] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [BookRentalShop] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [BookRentalShop] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [BookRentalShop] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [BookRentalShop] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [BookRentalShop] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [BookRentalShop] SET  MULTI_USER 
GO
ALTER DATABASE [BookRentalShop] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [BookRentalShop] SET DB_CHAINING OFF 
GO
ALTER DATABASE [BookRentalShop] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [BookRentalShop] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [BookRentalShop] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [BookRentalShop] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [BookRentalShop] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[bookstbl]

-- %%
USE [BookRentalShop]
GO

-- %%
/****** Object:  Table [dbo].[bookstbl]    Script Date: 2024-04-02 오후 12:59:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[bookstbl](
	[bookIdx] [int] IDENTITY(1,1) NOT NULL,
	[Author] [varchar](45) NULL,
	[Division] [char](4) NOT NULL,
	[Names] [varchar](100) NULL,
	[ReleaseDate] [date] NULL,
	[ISBN] [varchar](200) NULL,
	[Price] [decimal](10, 0) NULL,
 CONSTRAINT [PK__bookstbl__47504B363C12E306] PRIMARY KEY CLUSTERED 
(
	[bookIdx] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[divtbl]

-- %%
/****** Object:  Table [dbo].[divtbl]    Script Date: 2024-04-02 오후 12:59:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[divtbl](
	[Division] [char](4) NOT NULL,
	[Names] [varchar](45) NULL,
PRIMARY KEY CLUSTERED 
(
	[Division] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[membertbl]

-- %%
/****** Object:  Table [dbo].[membertbl]    Script Date: 2024-04-02 오후 12:59:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[membertbl](
	[memberIdx] [int] IDENTITY(1,1) NOT NULL,
	[Names] [varchar](45) NOT NULL,
	[Levels] [char](1) NULL,
	[Addr] [varchar](100) NULL,
	[Mobile] [varchar](13) NULL,
	[Email] [varchar](50) NULL,
 CONSTRAINT [PK__membertb__A6BF400B1232F82A] PRIMARY KEY CLUSTERED 
(
	[memberIdx] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[rentaltbl]

-- %%
/****** Object:  Table [dbo].[rentaltbl]    Script Date: 2024-04-02 오후 12:59:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[rentaltbl](
	[rentalIdx] [int] IDENTITY(1,1) NOT NULL,
	[memberIdx] [int] NULL,
	[bookIdx] [int] NULL,
	[rentalDate] [date] NULL,
	[returnDate] [date] NULL,
 CONSTRAINT [PK__rentaltb__51E4880D3DF22812] PRIMARY KEY CLUSTERED 
(
	[rentalIdx] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__bookstbl__Author__398D8EEE]

-- %%
ALTER TABLE [dbo].[bookstbl] ADD  CONSTRAINT [DF__bookstbl__Author__398D8EEE]  DEFAULT (NULL) FOR [Author]
GO

-- %% [markdown]
-- # [DF__bookstbl__Names__3B75D760]

-- %%
ALTER TABLE [dbo].[bookstbl] ADD  CONSTRAINT [DF__bookstbl__Names__3B75D760]  DEFAULT (NULL) FOR [Names]
GO

-- %% [markdown]
-- # [DF__bookstbl__Releas__3C69FB99]

-- %%
ALTER TABLE [dbo].[bookstbl] ADD  CONSTRAINT [DF__bookstbl__Releas__3C69FB99]  DEFAULT (NULL) FOR [ReleaseDate]
GO

-- %% [markdown]
-- # [DF__bookstbl__ISBN__3D5E1FD2]

-- %%
ALTER TABLE [dbo].[bookstbl] ADD  CONSTRAINT [DF__bookstbl__ISBN__3D5E1FD2]  DEFAULT (NULL) FOR [ISBN]
GO

-- %% [markdown]
-- # [DF__bookstbl__Price__3E52440B]

-- %%
ALTER TABLE [dbo].[bookstbl] ADD  CONSTRAINT [DF__bookstbl__Price__3E52440B]  DEFAULT (NULL) FOR [Price]
GO

-- %% [markdown]
-- # [DF__divtbl__Names__36B12243]

-- %%
ALTER TABLE [dbo].[divtbl] ADD  DEFAULT (NULL) FOR [Names]
GO

-- %% [markdown]
-- # [DF__membertbl__Level__412EB0B6]

-- %%
ALTER TABLE [dbo].[membertbl] ADD  CONSTRAINT [DF__membertbl__Level__412EB0B6]  DEFAULT (NULL) FOR [Levels]
GO

-- %% [markdown]
-- # [DF__membertbl__Addr__4222D4EF]

-- %%
ALTER TABLE [dbo].[membertbl] ADD  CONSTRAINT [DF__membertbl__Addr__4222D4EF]  DEFAULT (NULL) FOR [Addr]
GO

-- %% [markdown]
-- # [DF__membertbl__Mobil__4316F928]

-- %%
ALTER TABLE [dbo].[membertbl] ADD  CONSTRAINT [DF__membertbl__Mobil__4316F928]  DEFAULT (NULL) FOR [Mobile]
GO

-- %% [markdown]
-- # [DF__membertbl__Email__440B1D61]

-- %%
ALTER TABLE [dbo].[membertbl] ADD  CONSTRAINT [DF__membertbl__Email__440B1D61]  DEFAULT (NULL) FOR [Email]
GO

-- %% [markdown]
-- # [DF__rentaltbl__membe__46E78A0C]

-- %%
ALTER TABLE [dbo].[rentaltbl] ADD  CONSTRAINT [DF__rentaltbl__membe__46E78A0C]  DEFAULT (NULL) FOR [memberIdx]
GO

-- %% [markdown]
-- # [DF__rentaltbl__bookI__47DBAE45]

-- %%
ALTER TABLE [dbo].[rentaltbl] ADD  CONSTRAINT [DF__rentaltbl__bookI__47DBAE45]  DEFAULT (NULL) FOR [bookIdx]
GO

-- %% [markdown]
-- # [DF__rentaltbl__renta__48CFD27E]

-- %%
ALTER TABLE [dbo].[rentaltbl] ADD  CONSTRAINT [DF__rentaltbl__renta__48CFD27E]  DEFAULT (NULL) FOR [rentalDate]
GO

-- %% [markdown]
-- # [DF__rentaltbl__retur__49C3F6B7]

-- %%
ALTER TABLE [dbo].[rentaltbl] ADD  CONSTRAINT [DF__rentaltbl__retur__49C3F6B7]  DEFAULT (NULL) FOR [returnDate]
GO

-- %% [markdown]
-- # [FK__bookstbl__Divisi__3A81B327]

-- %%
ALTER TABLE [dbo].[bookstbl]  WITH CHECK ADD  CONSTRAINT [FK__bookstbl__Divisi__3A81B327] FOREIGN KEY([Division])
REFERENCES [dbo].[divtbl] ([Division])
GO
ALTER TABLE [dbo].[bookstbl] CHECK CONSTRAINT [FK__bookstbl__Divisi__3A81B327]
GO

-- %% [markdown]
-- # [fk_rentaltbl_bookstbl1]

-- %%
ALTER TABLE [dbo].[rentaltbl]  WITH CHECK ADD  CONSTRAINT [fk_rentaltbl_bookstbl1] FOREIGN KEY([bookIdx])
REFERENCES [dbo].[bookstbl] ([bookIdx])
GO
ALTER TABLE [dbo].[rentaltbl] CHECK CONSTRAINT [fk_rentaltbl_bookstbl1]
GO

-- %% [markdown]
-- # [fk_rentaltbl_membertbl1]

-- %%
ALTER TABLE [dbo].[rentaltbl]  WITH CHECK ADD  CONSTRAINT [fk_rentaltbl_membertbl1] FOREIGN KEY([memberIdx])
REFERENCES [dbo].[membertbl] ([memberIdx])
GO
ALTER TABLE [dbo].[rentaltbl] CHECK CONSTRAINT [fk_rentaltbl_membertbl1]
GO

-- %% [markdown]
-- # [BookRentalShop]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [BookRentalShop] SET  READ_WRITE 
GO
