# %% [markdown]
# ## 데이터 시각화 3
#
# ### 가장 일반적인 시각화 라이브러리 Matplotlib
#
# Python에서 가장 널리 사용되는 데이터 시각화 라이브러리입니다. 이 라이브러리는 2D 차트 및 그래프를 생성하는 데 사용되며, 과학적 데이터 시각화에 특히 유용

# %%
#설치
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Sine Wave')
plt.show()

# %% [markdown]
# #### Seaborn: Matplotlib을 기반 통계적 데이터 시각화
#
# - https://seaborn.pydata.org/examples/index.html 참조
#
# Matplotlib을 기반으로 한 라이브러리로 통계적 데이터 시각화 라이브러리

# %%
# 설치
# !pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="darkgrid")
df = sns.load_dataset('tips')

# 산점도 그래프
sns.relplot(df, x='total_bill', y='tip',
            hue="day", palette="Set1")

# 분포를 시각화하는 히스토그램
sns.displot(df, x='total_bill', hue="day", palette="pastel")

# 범주형 데이터를 시각화하는 박스 플롯
sns.catplot(df, x='day', y='total_bill', kind='box', hue="day", palette="Set3")

plt.show()

# %% [markdown]
# #### adjustText: 텍스트 레이블이 겹치지 않도록 자동 조정
#
# matplotlib과 함께 사용되는 파이썬 라이브러리로, 그래프 상의 텍스트 레이블이 겹치지 않도록 조정해주는 기능

# %%
# 설치
# !pip install adjustText

# %%
import matplotlib.pyplot as plt
from adjustText import adjust_text
import numpy as np

# 샘플 데이터 생성  
data_size = 40  
np.random.seed(0)  
x = np.random.randn(data_size)  
y = np.random.randn(data_size)
texts = [plt.text(x[i], y[i], f'Point {i}') for i in range(10)]

# 그래프 그리기
plt.scatter(x, y)

# 텍스트 레이블 조정 # 아래를 주석처리해서 확인해볼 것!
adjust_text(texts)

# 결과 표시
plt.show()

# %% [markdown]
# #### mpld3: 웹 친화적인 인터랙티브 그래픽
#
# Matplotlib 기반의 시각화를 웹 친화적인 인터랙티브 그래픽으로 변환하는 파이썬 라이브러리

# %%
# 설치
# !pip install mpld3

# %%
import matplotlib.pyplot as plt
import mpld3

# 샘플 데이터로 그래프 생성
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [10, 20, 25, 30], marker='o')

# mpld3를 사용하여 HTML로 변환
mpld3_html = mpld3.fig_to_html(fig)

# HTML 파일로 저장하거나 웹에서 직접 렌더링 할 수 있습니다.
with open("example_graph.html", "w") as f:
    f.write(mpld3_html)
# Out:
# d:\01_Programming\100_HugoBank\Mine\works-need-it-python\venv_thrd\lib\site-packages\mpld3\mplexporter\utils.py:300: MatplotlibDeprecationWarning: The converter attribute was deprecated in Matplotlib 3.10 and will be removed in 3.12. Use get_converter and set_converter methods instead.
#   isinstance(axis.converter, matplotlib.dates._SwitchableDateConverter)
# d:\01_Programming\100_HugoBank\Mine\works-need-it-python\venv_thrd\lib\site-packages\mpld3\mplexporter\utils.py:303: MatplotlibDeprecationWarning: The converter attribute was deprecated in Matplotlib 3.10 and will be removed in 3.12. Use get_converter and set_converter methods instead.
#   isinstance(axis.converter, matplotlib.dates.DateConverter)
# ...

# %% [markdown]
# #### mplfinance: 주식 시장 데이터 시각화 라이브러리
#
# 금융 데이터 시각화를 위해 특별히 설계된 Python 라이브러리

# %%
# 설치
# !pip install mplfinance

# %%
import mplfinance as mpf
import pandas as pd

# 데이터 불러오기
# 데이터는 'Date', 'Open', 'High', 'Low', 'Close', 'Volume' 컬럼을 포함해야 함
df = pd.read_csv('mplfinance_sample.csv', index_col=0, parse_dates=True)

# 캔들스틱 차트 생성
mpf.plot(df, type='candle', style='charles',
         title='Stock Price',
         ylabel='Price ($)',
         volume=True)

# %% [markdown]
# #### tikzplotlib: Matplotlib 그래프를 TikZ 코드로 변환
#
# 매트플롯립(Matplotlib) 그래프를 LaTeX에서 사용할 수 있는 TikZ/PGFPlots 코드로 변환해주는 라이브러리

# %%
# 설치
# !pip install tikzplotlib

# %%
import matplotlib.pyplot as plt
import tikzplotlib

# 데이터 생성
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]

# 매트플롯립을 사용한 그래프 그리기
plt.figure()
plt.plot(x, y)
plt.title("Simple Plot")
plt.xlabel("x")
plt.ylabel("y")

# tikzplotlib를 사용하여 TikZ 코드로 저장
tikzplotlib.save("myplot.tex")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 import tikzplotlib
#       4 # 데이터 생성
#       5 x = [1, 2, 3, 4]
#
# File d:\01_Programming\100_HugoBank\Mine\works-need-it-python\venv_thrd\lib\site-packages\tikzplotlib\__init__.py:5
#       3 from .__about__ import __version__
#       4 from ._cleanfigure import clean_figure
# ----> 5 from ._save import Flavors, get_tikz_code, save
#       7 __all__ = [
#       8     "__version__",
#       9     "get_tikz_code",
#    (...)
#      12     "Flavors",
#      13 ]
#
# File d:\01_Programming\100_HugoBank\Mine\works-need-it-python\venv_thrd\lib\site-packages\tikzplotlib\_save.py:11
#       8 import matplotlib as mpl
#       9 import matplotlib.pyplot as plt
# ---> 11 from . import _axes
#      12 from . import _image as img
# ...

# %% [markdown]
# ### NetworkX: 네트워크 구조의 모델링 및 시각화
#
# 복잡한 네트워크 구조를 생성, 조작, 분석, 모델링, 시각화, 그리고 저장하기 위한 강력한 라이브러리

# %% [markdown]
# <img src="https://wikidocs.net/images/page/229298/NetworkX_ex.png" width="700">

# %%
# 설치
# !pip install networkx

# %%
import networkx as nx
import matplotlib.pyplot as plt

# 그래프 객체 생성
G = nx.Graph()

# 노드 추가
G.add_node("A")
G.add_node("B")
G.add_node("C")

# 엣지 추가
G.add_edge("A", "B")
G.add_edge("B", "C")

# 최단 경로 계산
print(nx.shortest_path(G, "A", "C"))

# 시각화
pos = {"A": (0, 0), "B": (0.5, 0.5), "C": (1, 0)}
options = {
    "font_size": 30,
    "node_size": 3000,
    "node_color": "white",
    "edgecolors": "black",
    "linewidths": 5,
    "width": 5,
}
nx.draw_networkx(G, pos, **options)
plt.gca().margins(0.3)
plt.axis("off")
plt.show()
# Out:
# ['A', 'B', 'C']
