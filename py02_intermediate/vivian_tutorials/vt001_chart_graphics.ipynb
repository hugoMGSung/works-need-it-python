# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0, 10, 0.2)
y = np.sin(x)
fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %% [markdown]
# ### QtDesigner 열기
#
# 1. MainWindow로 열기
# 2. UI 디자인 후
# 3. 화면 중심의 QWidget 위젯 마우스 오른쪽 버튼 Promote to... 클릭
#
# 4. 종료 후 오른쪽 Object Inspector에서 아래와 같이 변경
#
# 5. GUI_chart 라는 이름의 파이썬 파일 생성
# 6. matplot_chart.py 파일 생성 작성
