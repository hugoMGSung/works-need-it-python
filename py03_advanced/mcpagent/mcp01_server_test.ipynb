# %% [markdown]
# ### 유튜브 테스트용 모듈

# %%
## 영상용 api 키, 하고 바로 삭제하기
import requests
import re
from dotenv import load_dotenv
import os
import xml.etree.ElementTree as ET
from datetime import datetime
from pprint import pprint
from youtube_transcript_api import YouTubeTranscriptApi

# %%
load_dotenv()
# Out:
# True

# %%
YOUTUBE_API_KEY = os.getenv('YOUTUBE_API_KEY')
YOUTUBE_API_URL = 'https://www.googleapis.com/youtube/v3'

# %% [markdown]
# #### 유튜브 자막 가져오기 함수

# %%
def get_youtube_transcript(url: str) -> str:
    """ 유튜브 영상 URL에 대한 자막을 가져옵니다."""
    
    # 1. 유튜브 URL에서 비디오 ID를 추출합니다.
    video_id_match = re.search(r"(?:v=|\/)([0-9A-Za-z_-]{11}).*", url)
    if not video_id_match:
        raise ValueError("유효하지 않은 YouTube URL이 제공되었습니다")
    video_id = video_id_match.group(1)
    
    languages = ["ko", "en"]
    # 2. youtube_transcript_api를 사용하여 자막을 가져옵니다.
    try:
        transcript_list = YouTubeTranscriptApi.get_transcript(video_id, languages=languages)
        
        # 3. 자막 목록의 'text' 부분을 하나의 문자열로 결합합니다.
        transcript_text = " ".join([entry["text"] for entry in transcript_list])
        return transcript_text

    except Exception as e:
        raise RuntimeError(f"비디오 ID '{video_id}'에 대한 자막을 찾을 수 없거나 사용할 수 없습니다.{e}")

# %%
transcript = get_youtube_transcript('https://youtu.be/aLXwRnBTsWI?si=OUSon5PdIUHE6BFH') # ChatGPT로 60억번 23살 청년
pprint(transcript) # "notebook.output.wordWrap": true in settings.json
# Out:
# ('made about million in revenue. GPTobile app이 [음악] 친구 나이가 23. 그런데 이미 수십억 원의 '
#  '매출을 만드는 앱 창업가입니다. 그런데이 친구 알아보니까 처음부터 잘 나간 건 아니에요. 가난 속에서 살았고 아버지의 병을 지켜봤고 '
#  '그리고 이런 책임감들이 그를 더욱더 강력하게 움지게 만들었죠. 그래서 그는 결심합니다. 내가 돈을 벌어야겠다. 그리고 중요한 건이 친구가 '
#  '개발자도 디자이너도 아니었다는 거예요. 그냥 그저 채 GPT한테 이렇게 물었죠. 모바일 앱은 어떻게 만들죠? 하고 그냥 친 거죠. 진짜이 '
#  '한 문장에서 시작된 그의 여정입니다. 그의 첫 단 한 달 만에 출시됐고 SNS 영상 딱 두 개로 바로 그 두 개로 월출 8만 달러. '
#  '그래서 블레이크가 말했습니다. 중요한 건 기술이 아니라 문제를 해결하려는 그 너의 태도다. 어, 블레이크가 대학교를 다닐 때 뭐 졸업에는 '
#  '애초에 관심도 없었고 직상에 취업하는 것도 관심이 없었다고 합니다. 이제 대학교 때 룸메이트가 있었는데 이제 룸메이트가 블레이크한테 종종 '
#  '물었대요. 야, 내가이 데이트 앱을 쓰고 있는데 채팅이 왔어.이 여자한테 뭐라고 답장하면 좋을까? 그때 블레이크가 아마 생각이 난 거 '
#  '같아요. 딱 떠올랐어요. 이거 그냥 AI가 해 주면 되지 않나? 그렇게 만들어진 앱이 바로 리지 GPT. 방식은 엄청 간단합니다. '
#  '스크린샷 올리면 AI가 센스 있게 답장을 만들어 주는 거예요. 복잡한 기술도 없어요. GPT 그리고 OCR 끝. 근데 이게 SNNS랑 '
#  '아주 찰떡처럼 잘 맞으면서 일주일 만에 20만 다운로드를 기록했고 월매출 2억 원 달성했습니다. 대단하죠? 그리고 여기서 우리 모두가 '
#  '주목해야 될 포인트는 블레이크가 뭐를 해서 얼마를 벌었다? 며칠 만에 얼마를 벌었다? 얼만큼 성공했다? 얼만큼 다운로드 받았다. 이게 '
#  '되게 도파민의 도파민을 자극하는 그런 수치긴 하지만 중요한게 아닙니다. 정확한 문제, 정확한 타겟, 문제랑 누구한테 마케팅을 할지 이거를 '
#  '정확하게 블레이크는 판단하고 있었던 거예요. 이거를 봐야 됩니다. 남자들이 데이트에서 어떻게 말해야 할지 고민하 고민하는 그 마음 그 '
#  '니즈를 정확히 캐치한 거죠. 남자들은 좋아하는 여자를 만나기 위해서라면 돈을 쓴다.이 바로 간단한 심리. 누구나 알고 있는이 니즈를 '
#  '비즈니스화 시킨 거죠. 블레이크는이 경험을 통해 한 번 더 확신하게 됩니다. 복잡한 기술보다는 명확한 문제 해결 그리고 명확한 타깃을 '
#  '위한 컨텐츠와 그리고 그 컨텐츠를 어떻게 배포하는 전략 이게 가장 중요하다고 다시 한번 느끼게 됩니다. 어 여기서 지금까지 이제 '
#  '블레이크가 첫 번째로 런칭한 앱에 대해서 한번 살펴봤는데 제 생각은 이렇습니다. 기술이 중요한게 아닙니다. 블레이크가 말했듯이 뭐 코드를 '
#  '써서 개발을 하거나 노 코드를 써서 개발을 하거나 요즘 핫한 바이브 코딩을 써서 개발을 하거나 그 서비스를 이용하는 사람은 전혀 관심 '
#  '없는 문제입니다. 그리고 며칠에 걸려서 개발을 했는지 뭐 얼마나 버그가 많았는지 아무 상관없습니다. 그냥이 서비스가 진짜로 필요한 사람이 '
#  '있는지 그리고 그 필요한 서비스를 어떻게 그 타겟하는 유저한테 전달을 했는지이 점이 모든 창업을 준비하시는 분들이라면 다시 한번 생각해 '
#  '보셔야 되는 주제 같습니다. 제가 아무리 이렇게 말해도 이거는 정말 교과서적인 말이고 모두가 알고 있는 내용이잖아요. 그런데 다들 안 '
#  '합니다. 99% 개발하시는 분들은 먼저 비용에 타협합니다. 어떤 걸로 만드는게 싸나 어떤 걸로 만들어야지 빨리 만드나. 근데 이런 걸 '
#  '타협할 시간에 어떻게 하면은 본인의 서비스가 타겟하는 유저한테 더욱더 매력적으로 어필될지 그 부분에 종하세요. 블레이크를 보면은 어쩌면 '
#  '저는 참 개차반이에요. 지난 2년 동안 총 일곱 개 여덟 개 개인적인 프로젝트를 진행하면서 지금까지 단 한 개도 이어온 프로젝트가 '
#  '없습니다. 이거를 통해서 객관적으로 제가 실행했던 실수들을 보면은 일단 이걸 만들고 싶어서 만들었죠. 근데 그 전에 어떻게 운영해야 '
#  '되는지, 어떤 식으로 수익화를 할지, 그리고 이걸 어떤 식으로 원하는 사람한테 전달을 할지, 그리고 무엇보다 중요한 거는 제가 필요한 '
#  '서비스였지 많은 대중이 필요한 서비스가 아니었어요. 이렇게 개발사를 운영하는 대표도 이런 실수를 합니다. 그러기 때문에 다시 한번 생각해 '
#  '보세요. 본인의 아이디어가 얼마나 사람들한테 필요한지 생각해 보세요. 그리고 또 하나 외모 자기 관리 앱 유맥스입니다. GPT 비전 '
#  'API를 써서 사진 올리면 피부, 눈, 헤어스타일 분석하고 관리 팁까지 줘요. 어, 참고로 저희 이피니티 회사에서도 이런 피부 관리 앱을 '
#  '아주 비슷하게 어, 제작한 사례가 있습니다.이 U맥스 프로젝트는 정확한 타겟이 정해져 있었어요. 첫 번째, 자신감을 높이고 싶은 고객들, '
#  '그리고 외모에 관심이 많은 사람들. 그리고 이렇게 딱 두 개를 겨냥하는 솔루션을 만들었고 그 결과는 출시 2개월 만에 월매출 5억 원 '
#  '달성 누적 매출액 약 40억 달성했습니다. 자, 그럼 이제 여기서 또 드는 생각이 있죠? 아니, 아무리 GPT가 도와준다지만 앱을 어떻게 '
#  '이렇게 쉽게 만들어? 그냥 뚝딱하면 한 개 만들어 놓고 뚝딱하면 또 한 개 만들고. 그리고 그게 또 성공까지 해요. 참 인생 사는게 쉬워 '
#  '보이죠? 부자되는 것도 쉽고. GPT만 있으면 다 하는데 뭐 그런데 다시 생각해 보면 블레이크가 만든 기능 자체가 엄청 복잡한 건 '
#  '아니에요. 다시 한번 말하지만 기능보다 중요한 건 바로 기획력 그리고 그 기획한 걸 실행하는 실행력 그리고 그걸 이어갈 수 있는 '
#  '집중력입니다. 그리고 분명한 건 GPT 하나 쓴다고 이런 성과가 나오는게 절대 아니에요. 그러면 주변에 GPT 쓰시는 분들 전부 다 '
#  '부자가 아니잖아요. 그것만 봐도 딱 답이 나오죠. GPT를 써서 실제로 성공하시는 분들이 있고 아닌 분들이 있습니다. 애초에 똑같았어요. '
#  '저희는 모두에게 똑같은 24시간이 있는데 24시간을 어떻게 쓰냐에 따라서 성공을 하고 실패를 하죠.이 뒤에는 어떤 기술이 나와도 바꿀 수 '
#  '없는 단 한 가지가 있습니다. 실패와 성공을 가르는 단 한 가지. 교과서에도 계속 말해 주는 거. 모두가 알고 있지만 힘든 거 바로 '
#  '노력과 실행입니다. 어, 블레이크를 인용하자면은 가난도 비전도 그 무엇도 없던 나도 여기까지 올 수 있었습니다. 처음엔 그냥 뭔가 해보고 '
#  '싶었을 뿐이었다는 거. 기술이 아니라 용기, 자격이 아니라 집중, 경력이 아니라 실행. 그게 그의 무기였고 우리 모두의 가장 큰 무기이자 '
#  '자산입니다. 그리고 지금이 영상을 보고 있는 여러분도 실행할 수 있어요. 시작할 수 있어요. 바로 딱 한 가지 질문에서 나도 해볼 수 '
#  '있을까? 저도 해 볼 수 있을까요? 저도요. 비전공자로서 노코드 툴인 버블에 입문했고 지금이 툴을 써서 저희 서비스를 직접 개발하고 '
#  '운용하고 먹고 살고 있습니다. 여기서 알아두시면 좋을게 버블은 아무도 몰라요. 대중적으로 아무도 모릅니다. 그리고 저희 부모님도 그랬듯이 '
#  '이걸로 돈을 어떻게 벌어? 노 코드가 개발이야. 그런데 개발이건 노코드건 코드건 중요한게 아니에요. 이걸로 뭔가를 하고 돈을 벌고 그리고 '
#  '그거를 운영하고 있다는 것 그게 중요한 거죠. 그러니까 주변 시선을 너무 신경 쓰지 마세요. 저도 블레이크처럼 그냥 뭔가 진행해 보고 '
#  '싶은 마음으로 시작했어요. 그리고 매일 조금씩 지금도 계속 나아가고 있습니다. 여러분도 분명히 있겠죠? 만들고 싶은 거, 하고 싶은 거 '
#  '댓글로 남겨 주시고 저희와 공유해요. 그냥 생각만 하고 있는 것보다 글로 남겼을 때 기억이 더 오래 가거든요. 함께 나아가는 사람이 '
#  '많을수록 더 멀리 갈 수도 있고요.이 영상이 유익하셨다면 좋아요와 구독 꾹 부탁드립니다.워 watch your girl. to and I '
#  'know are feel the [음악]')

# %%
def search_youtube_videos(query: str) :
    """유튜브에서 특정 키워드로 동영상을 검색하고 세부 정보를 가져옵니다"""
    try:
        # 1. 동영상 검색
        max_results: int = 20
        search_url = f"{YOUTUBE_API_URL}/search?part=snippet&q={requests.utils.quote(query)}&type=video&maxResults={max_results}&key={YOUTUBE_API_KEY}"
        print(f"Searching YouTube with URL: {search_url}")

        search_response = requests.get(search_url)
        search_data = search_response.json()
        video_ids = [item['id']['videoId'] for item in search_data.get('items', [])]

        if not video_ids:
            print("No videos found for the query.")
            return []

        video_details_url = f"{YOUTUBE_API_URL}/videos?part=snippet,statistics&id={','.join(video_ids)}&key={YOUTUBE_API_KEY}"
        print(f"영상 정보 가져오는 중: {video_details_url}")
        details_response = requests.get(video_details_url)
        details_response.raise_for_status()
        details_data = details_response.json()

        videos = []
        for item in details_data.get('items', []):
            snippet = item.get('snippet', {})
            statistics = item.get('statistics', {})
            thumbnails = snippet.get('thumbnails', {})
            high_thumbnail = thumbnails.get('high', {}) 
            view_count = statistics.get('viewCount')
            like_count = statistics.get('likeCount')

            video_card = {
                "title": snippet.get('title', 'N/A'),
                "publishedDate": snippet.get('publishedAt', ''),
                "channelName": snippet.get('channelTitle', 'N/A'),
                "channelId": snippet.get('channelId', ''),
                "thumbnailUrl": high_thumbnail.get('url', ''),
                "viewCount": int(view_count) if view_count is not None else None,
                "likeCount": int(like_count) if like_count is not None else None,
                "url": f"https://www.youtube.com/watch?v={item.get('id', '')}",
            }
            videos.append(video_card)

        if not videos:
            print("No video details could be fetched.")
            return []

        return videos

    except Exception as e:
        print(f"Error: {e}")
        return []

# %%
videos = search_youtube_videos('ChatGPT 활용')
for video in videos:
    pprint(video)
# Out:
# Searching YouTube with URL: https://www.googleapis.com/youtube/v3/search?part=snippet&q=ChatGPT%20%ED%99%9C%EC%9A%A9&type=video&maxResults=20&key=AIzaSyBl_T8QPr4GB2QeWgmk3BRd7ZC7Ob5vMX8
# 영상 정보 가져오는 중: https://www.googleapis.com/youtube/v3/videos?part=snippet,statistics&id=aGMS6j8kFrA,yux_9YJ9YcM,IzzXx5g7Jdw,k-5M06S1GIs,ovv3UOfUMys,xOfax3H3O00,YPa1B7AJ_zI,vLgZWduVzWo,mQuo8Rw3mv0,xAUuLECuyd0,6UH74jsEk5A,fS0JnWnocos,i1VqqX4iAZ0,oardd0VJLZg,TIr6_Bo8zfg,0KtfbY5m_bU,dLzjQUFMme4,WBdtG97V-T8,CmkyAo6PN2k,jwvnctA0qBw&key=AIzaSyBl_T8QPr4GB2QeWgmk3BRd7ZC7Ob5vMX8
# {'channelId': 'UCZ6UHYBQFBe14WUgxlgmYfg',
#  'channelName': '오빠두엑셀 l 엑셀 강의 대표채널',
#  'likeCount': 40443,
#  'publishedDate': '2024-10-02T13:35:00Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/aGMS6j8kFrA/hqdefault.jpg',
#  'title': '엑셀 데이터 입력, 10초 안에 끝내세요! ChatGPT 꿀팁 대공개⚡#shorts',
#  'url': 'https://www.youtube.com/watch?v=aGMS6j8kFrA',
#  'viewCount': 2093447}
# {'channelId': 'UChu25pJgVZB3p0dVEgmU0PQ',
#  'channelName': '메타코드M',
#  'likeCount': 2283,
#  'publishedDate': '2023-03-06T09:00:37Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/yux_9YJ9YcM/hqdefault.jpg',
#  'title': 'ChatGPT 초보자도 8분이면 사용법 마스터합니다ㅣ서울대 AI박사과정',
#  'url': 'https://www.youtube.com/watch?v=yux_9YJ9YcM',
#  'viewCount': 170784}
# {'channelId': 'UChLHvrqxYRGFdHCVEReD0GQ',
#  'channelName': '기묘한 자동화',
#  'likeCount': 263,
#  'publishedDate': '2024-06-04T23:00:14Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/IzzXx5g7Jdw/hqdefault.jpg',
#  'title': '샘 알트만이 주목한 GPT-4o 활용법 | GPT-4o 활용은 이렇게  #shotrs #ai #chatgpt #gpt4o',
#  'url': 'https://www.youtube.com/watch?v=IzzXx5g7Jdw',
#  'viewCount': 36678}
# {'channelId': 'UC-f3A4v6fLtRLAyfNT32Qrw',
#  'channelName': 'AIEdgeX',
#  'likeCount': 5430,
#  'publishedDate': '2023-03-17T13:00:38Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/k-5M06S1GIs/hqdefault.jpg',
#  'title': 'ChatGPT로 돈버는 방법 9가지 요약',
#  'url': 'https://www.youtube.com/watch?v=k-5M06S1GIs',
#  'viewCount': 432834}
# {'channelId': 'UCf9yTGvaf5HL8CCPxIanENg',
#  'channelName': '알린 ALINN',
#  'likeCount': 33364,
#  'publishedDate': '2025-01-17T06:05:39Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/ovv3UOfUMys/hqdefault.jpg',
#  'title': "늦게 알면 '폭풍 오열'할 챗GPT 꿀기능",
#  'url': 'https://www.youtube.com/watch?v=ovv3UOfUMys',
#  'viewCount': 1932004}
# {'channelId': 'UCk_xkR8ORNwtMkaffvYArGA',
#  'channelName': '디자인하는AI',
#  'likeCount': 9106,
#  'publishedDate': '2024-11-22T09:19:09Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/xOfax3H3O00/hqdefault.jpg',
#  'title': '당신의 문제를 해결해 줄 효율 200%의 6가지 ChatGPT 활용법 (Feat. Udemy)',
#  'url': 'https://www.youtube.com/watch?v=xOfax3H3O00',
#  'viewCount': 231245}
# {'channelId': 'UCA_hgsFzmynpv1zkvA5A7jA',
#  'channelName': '지식인사이드',
#  'likeCount': 24725,
#  'publishedDate': '2025-04-18T09:30:30Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/YPa1B7AJ_zI/hqdefault.jpg',
#  'title': "상위 1% 고수들만 안다는 챗GPT의 숨은 기능 '3가지'ㅣ지식인초대석 EP.36 (김덕진 교수 1부)",
#  'url': 'https://www.youtube.com/watch?v=YPa1B7AJ_zI',
#  'viewCount': 1245201}
# {'channelId': 'UCdNqxwnqpXJpMt47WE7Bwwg',
#  'channelName': '커리어해커 알렉스',
#  'likeCount': 3784,
#  'publishedDate': '2024-04-02T08:14:12Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/vLgZWduVzWo/hqdefault.jpg',
#  'title': '사람들이 잘 모르는 챗GPT 꿀팁 기능 5가지!! #챗gpt #인공지능 #꿀팁',
#  'url': 'https://www.youtube.com/watch?v=vLgZWduVzWo',
#  'viewCount': 239737}
# {'channelId': 'UCe3tNN8GKWRMPJzJj4nLrbA',
#  'channelName': '챗GPT전문강사_김미혜',
#  'likeCount': 8,
#  'publishedDate': '2025-05-04T13:49:54Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/mQuo8Rw3mv0/hqdefault.jpg',
#  'title': '#챗GPT #챗GPT강사 #미래교육아카데미 #한국강사교육협회 #AI교육 #챗GPT전문강사_손정영 #챗GPT활용   '
#           '#챗GPT전문강사_정덕영 #챗GPT전문강사_김미혜',
#  'url': 'https://www.youtube.com/watch?v=mQuo8Rw3mv0',
#  'viewCount': 312}
# {'channelId': 'UCXxtwdYcghpqmfb9YyHV0Fg',
#  'channelName': '국립중앙과학관',
#  'likeCount': 6504,
#  'publishedDate': '2023-03-20T09:15:03Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/xAUuLECuyd0/hqdefault.jpg',
#  'title': '챗GPT 어렵다구요..? 챗GPT (ChatGPT) 사용법 4분만에 배우기(회원가입, 질문방법, 번역하기 등) '
#           '#chatGPT #챗GPT #사용법',
#  'url': 'https://www.youtube.com/watch?v=xAUuLECuyd0',
#  'viewCount': 635704}
# {'channelId': 'UCdNqxwnqpXJpMt47WE7Bwwg',
#  'channelName': '커리어해커 알렉스',
#  'likeCount': 13818,
#  'publishedDate': '2023-12-19T08:15:00Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/6UH74jsEk5A/hqdefault.jpg',
#  'title': '상위 1% 챗GPT 고수들만 아는 초간단 사용법 3가지',
#  'url': 'https://www.youtube.com/watch?v=6UH74jsEk5A',
#  'viewCount': 542176}
# {'channelId': 'UCf9yTGvaf5HL8CCPxIanENg',
#  'channelName': '알린 ALINN',
#  'likeCount': 1476,
#  'publishedDate': '2025-02-20T01:21:53Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/fS0JnWnocos/hqdefault.jpg',
#  'title': "놓치면 '평생 후회'할 챗GPT 미친 꿀기능",
#  'url': 'https://www.youtube.com/watch?v=fS0JnWnocos',
#  'viewCount': 40321}
# {'channelId': 'UCkxbPwdaV74Erdxt97Nt23w',
#  'channelName': '공부왕찐천재 홍진경',
#  'likeCount': 17630,
#  'publishedDate': '2023-06-15T09:30:09Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/i1VqqX4iAZ0/hqdefault.jpg',
#  'title': "[챗GPT] 이보다 쉬운 설명은 없다 '챗GPT' (홍진경,안될과학,궤도, eng)",
#  'url': 'https://www.youtube.com/watch?v=i1VqqX4iAZ0',
#  'viewCount': 1397839}
# {'channelId': 'UC-6DLwseTZG-l4JprVV2MIQ',
#  'channelName': '유튜브신쌤',
#  'likeCount': 297,
#  'publishedDate': '2025-04-20T12:01:24Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/oardd0VJLZg/hqdefault.jpg',
#  'title': 'AI 초보자를 위한 스마트폰 챗GPT 활용 가이드 | 무료&유료 비교 (2025 최신 Ver.)',
#  'url': 'https://www.youtube.com/watch?v=oardd0VJLZg',
#  'viewCount': 19526}
# {'channelId': 'UCrV2hO-zcxTsZRR6l0nTlFw',
#  'channelName': 'AI김박사',
#  'likeCount': 30497,
#  'publishedDate': '2025-04-04T08:29:41Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/TIr6_Bo8zfg/hqdefault.jpg',
#  'title': '상위 0.1%들의 챗GPT 미친 사용법',
#  'url': 'https://www.youtube.com/watch?v=TIr6_Bo8zfg',
#  'viewCount': 1962378}
# {'channelId': 'UCdNqxwnqpXJpMt47WE7Bwwg',
#  'channelName': '커리어해커 알렉스',
#  'likeCount': 2152,
#  'publishedDate': '2024-02-26T08:30:59Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/0KtfbY5m_bU/hqdefault.jpg',
#  'title': '인공지능 GPTs로 업무 생산성 미친듯이 끌어올리기! ChatGPT 실전 활용 완벽 가이드',
#  'url': 'https://www.youtube.com/watch?v=0KtfbY5m_bU',
#  'viewCount': 75893}
# {'channelId': 'UCXh_55-DSbC1_tHc2oZcDcQ',
#  'channelName': 'N잡학교',
#  'likeCount': 256,
#  'publishedDate': '2024-08-05T04:01:38Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/dLzjQUFMme4/hqdefault.jpg',
#  'title': 'AI 챗GPT 활용해서 왕초보도 자면서 돈버는 방법',
#  'url': 'https://www.youtube.com/watch?v=dLzjQUFMme4',
#  'viewCount': 19603}
# {'channelId': 'UCf9yTGvaf5HL8CCPxIanENg',
#  'channelName': '알린 ALINN',
#  'likeCount': 17302,
#  'publishedDate': '2025-01-12T16:22:35Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/WBdtG97V-T8/hqdefault.jpg',
#  'title': "이걸 몰랐을 테니까.. l 대부분은 모르는 챗GPT '제대로' 쓰는 법",
#  'url': 'https://www.youtube.com/watch?v=WBdtG97V-T8',
#  'viewCount': 306654}
# {'channelId': 'UCzLEg_ekrLbKa-HZS85qy_A',
#  'channelName': 'AI 지성의숲 : 성필원 작가',
#  'likeCount': 250,
#  'publishedDate': '2025-02-27T04:31:30Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/CmkyAo6PN2k/hqdefault.jpg',
#  'title': 'ChatGPT를 100% 활용하는 방법',
#  'url': 'https://www.youtube.com/watch?v=CmkyAo6PN2k',
#  'viewCount': 8126}
# {'channelId': 'UCZ6UHYBQFBe14WUgxlgmYfg',
#  'channelName': '오빠두엑셀 l 엑셀 강의 대표채널',
#  'likeCount': 1162,
#  'publishedDate': '2025-01-16T13:35:02Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/jwvnctA0qBw/hqdefault.jpg',
#  'title': '엑셀·워드·PPT 자동화, 이 영상 하나로 끝내세요! | ChatGPT 활용, 60분 마스터 클래스',
#  'url': 'https://www.youtube.com/watch?v=jwvnctA0qBw',
#  'viewCount': 39490}

# %%
def get_channel_info(video_url: str) -> dict:
    """YouTube 동영상 URL로부터 채널 정보와 최근 5개의 동영상을 가져옵니다"""
    def extract_video_id(url):
        match = re.search(r"(?:v=|\/)([0-9A-Za-z_-]{11})", url)
        return match.group(1) if match else None
    def fetch_recent_videos(channel_id):
        rss_url = f"https://www.youtube.com/feeds/videos.xml?channel_id={channel_id}"
        try:
            response = requests.get(rss_url)
            if response.status_code != 200:
                return []

            root = ET.fromstring(response.text)
            ns = {'atom': 'http://www.w3.org/2005/Atom'}
            videos = []

            for entry in root.findall('.//atom:entry', ns)[:5]:  
                title = entry.find('./atom:title', ns).text
                link = entry.find('./atom:link', ns).attrib['href']
                published = entry.find('./atom:published', ns).text
                videos.append({
                    'title': title,
                    'link': link,
                    'published': published,
                    'updatedDate': datetime.now().strftime("%Y-%m-%d %H:%M:%S")
                })

            return videos
        except:
            return []

    video_id = extract_video_id(video_url)
    if not video_id:
        raise ValueError("Invalid YouTube URL")

    video_api = f"{YOUTUBE_API_URL}/videos?part=snippet,statistics&id={video_id}&key={YOUTUBE_API_KEY}"
    video_data = requests.get(video_api).json()
    if not video_data.get('items'):
        raise ValueError("No video found")

    video_info = video_data['items'][0]
    channel_id = video_info['snippet']['channelId']

    channel_api = f"{YOUTUBE_API_URL}/channels?part=snippet,statistics&id={channel_id}&key={YOUTUBE_API_KEY}"
    channel_data = requests.get(channel_api).json()['items'][0]

    return {
        'channelTitle': channel_data['snippet']['title'],
        'channelUrl': f"https://www.youtube.com/channel/{channel_id}",
        'subscriberCount': channel_data['statistics'].get('subscriberCount', '0'),
        'viewCount': channel_data['statistics'].get('viewCount', '0'),
        'videoCount': channel_data['statistics'].get('videoCount', '0'),
        'videos': fetch_recent_videos(channel_id)
    }

# %%
pprint(get_channel_info("https://www.youtube.com/watch?v=gYqs-wUKZsM")) ## openai 영상
# Out:
# {'channelTitle': 'OpenAI',
#  'channelUrl': 'https://www.youtube.com/channel/UCXZCJLdBC09xxGZ6gcdrc6A',
#  'subscriberCount': '1510000',
#  'videoCount': '279',
#  'videos': [{'link': 'https://www.youtube.com/watch?v=nN65VbhKCxU',
#              'published': '2025-05-02T20:01:22+00:00',
#              'title': 'ChatGPT Has Multiple Voices?!',
#              'updatedDate': '2025-05-06 15:24:45'},
#             {'link': 'https://www.youtube.com/watch?v=0dhX84UkwFs',
#              'published': '2025-04-23T15:29:02+00:00',
#              'title': 'How to make Sora music videos with David Sheldrick',
#              'updatedDate': '2025-05-06 15:24:45'},
#             {'link': 'https://www.youtube.com/watch?v=FUq9qRwrDrI',
#              'published': '2025-04-16T18:18:29+00:00',
#              'title': 'OpenAI Codex CLI',
#              'updatedDate': '2025-05-06 15:24:45'},
#             {'link': 'https://www.youtube.com/watch?v=sq8GBPUb3rk',
#              'published': '2025-04-16T17:33:32+00:00',
#              'title': 'OpenAI o3 & o4-mini',
#              'updatedDate': '2025-05-06 15:24:45'},
#             {'link': 'https://www.youtube.com/watch?v=PZk4t7Np4Ds',
#              'published': '2025-04-14T23:57:11+00:00',
#              'title': 'World-building in Sora with Alexia Adana',
#              'updatedDate': '2025-05-06 15:24:45'}],
#  'viewCount': '71908058'}
